# %% [markdown]
# ![logo_ironhack_blue 7](https://user-images.githubusercontent.com/23629340/40541063-a07a0a8a-601a-11e8-91b5-2f13e4e6b441.png)
#
# # Lab | Cleaning categorical data
#
# For this lab, we will be using the dataset in the Customer Analysis Business Case. This dataset can be found in `files_for_lab` folder. In this lab we will explore categorical data.

# %% [markdown]
# ### Instructions

# %% [markdown]
# 1. Import the necessary libraries if you are starting a new notebook.
# Using the same data as the previous lab: we_fn_use_c_marketing_customer_value_analysis.csv

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
customer_df = pd.read_csv('we_fn_use_c_marketing_customer_value_analysis.csv')

# %% [markdown]
# 2. Find  all of the categorical data.  Save it in a categorical_df variable.

# %%
categorical_df = customer_df.select_dtypes(object)

# %%
categorical_df
# Out:
#      Customer       State Response  Coverage Education Effective To Date  \
# 0     BU79786  Washington       No     Basic  Bachelor           2/24/11
# 1     QZ44356     Arizona       No  Extended  Bachelor           1/31/11
# 2     AI49188      Nevada       No   Premium  Bachelor           2/19/11
# 3     WW63253  California       No     Basic  Bachelor           1/20/11
# 4     HB64268  Washington       No     Basic  Bachelor            2/3/11
# ...       ...         ...      ...       ...       ...               ...
# 9129  LA72316  California       No     Basic  Bachelor           2/10/11
# 9130  PK87824  California      Yes  Extended   College           2/12/11
# 9131  TD14365  California       No  Extended  Bachelor            2/6/11
# 9132  UP19263  California       No  Extended   College            2/3/11
# 9133  Y167826  California       No  Extended   College           2/14/11
#
#      EmploymentStatus Gender Location Code Marital Status     Policy Type  \
# ...

# %% [markdown]
# 3. Check for NaN values.

# %%
categorical_df.isna().sum()
# Out:
# Customer             0
# State                0
# Response             0
# Coverage             0
# Education            0
# Effective To Date    0
# EmploymentStatus     0
# Gender               0
# Location Code        0
# Marital Status       0
# Policy Type          0
# Policy               0
# Renew Offer Type     0
# Sales Channel        0
# Vehicle Class        0
# Vehicle Size         0
# dtype: int64

# %% [markdown]
# 4. Check all unique values of columns.

# %%
for x in customer_df:
    print(x,len(pd.unique(customer_df[x].values.ravel('K')))) #customer_df.state.nunique()
# Out:
# Customer 9134
# State 5
# Customer Lifetime Value 8041
# Response 2
# Coverage 3
# Education 5
# Effective To Date 59
# EmploymentStatus 5
# Gender 2
# Income 5694
# Location Code 3
# Marital Status 3
# Monthly Premium Auto 202
# Months Since Last Claim 36
# Months Since Policy Inception 100
# Number of Open Complaints 6
# Number of Policies 9
# Policy Type 3
# Policy 9
# Renew Offer Type 4
# Sales Channel 4
# Total Claim Amount 5106
# Vehicle Class 6
# Vehicle Size 3

# %% [markdown]
# 5. Check dtypes. Do they all make sense as categorical data?

# %%
categorical_df.dtypes
# Out:
# Customer             object
# State                object
# Response             object
# Coverage             object
# Education            object
# Effective To Date    object
# EmploymentStatus     object
# Gender               object
# Location Code        object
# Marital Status       object
# Policy Type          object
# Policy               object
# Renew Offer Type     object
# Sales Channel        object
# Vehicle Class        object
# Vehicle Size         object
# dtype: object

# %%
# 'Effective To Date' should be a date-time type variable
# 'Response' could be a Boolean

# %%
categorical_df
# Out:
#      Customer       State Response  Coverage Education Effective To Date  \
# 0     BU79786  Washington       No     Basic  Bachelor           2/24/11
# 1     QZ44356     Arizona       No  Extended  Bachelor           1/31/11
# 2     AI49188      Nevada       No   Premium  Bachelor           2/19/11
# 3     WW63253  California       No     Basic  Bachelor           1/20/11
# 4     HB64268  Washington       No     Basic  Bachelor            2/3/11
# ...       ...         ...      ...       ...       ...               ...
# 9129  LA72316  California       No     Basic  Bachelor           2/10/11
# 9130  PK87824  California      Yes  Extended   College           2/12/11
# 9131  TD14365  California       No  Extended  Bachelor            2/6/11
# 9132  UP19263  California       No  Extended   College            2/3/11
# 9133  Y167826  California       No  Extended   College           2/14/11
#
#      EmploymentStatus Gender Location Code Marital Status     Policy Type  \
# ...

# %% [markdown]
# 6. Does any column contain alpha and numeric data?  Decide how to clean it.

# %% [markdown]
# As far as I am concerned, alpha and numeric data refers to latin alphabet and arabic numbers. Ergo A-Z/a-z & 0-9. Therefore all the data in the DataFrame is alpha and numeric data

# %% [markdown]
# Making a broader interpretation, we can understand that the question refers to both kinds of data in the same cell. We can also interpretate a reference to the following characters #,@,&,%,?,!,-,:,€,$,',"

# %%
character=[]
for columns in categorical_df:
    if "#,@,&,%,?,!,-,:,€,$,'," in columns:
        character.append(columns)

# %%
character
# Out:
# []

# %% [markdown]
# As we can see, there is no special characters in the DataFrame

# %% [markdown]
# Having said all the above, I understand it is asking for the second asumption: refers to both kinds of data in the same cell.
# The two columns that present the aforementioned characteristics are Customer and Policy.
# To deal with them, I am going to drop Customer and insert the number in a new column named 'L'

# %%
categorical_df = categorical_df.drop('Customer', axis=1) # Drop Customer column

# %%
categorical_df = categorical_df.drop('Policy', axis=1) # Identify de distinct discrete variables in the column

# %%
categorical_df.head()
# Out:
#         State Response  Coverage Education Effective To Date EmploymentStatus  \
# 0  Washington       No     Basic  Bachelor           2/24/11         Employed
# 1     Arizona       No  Extended  Bachelor           1/31/11       Unemployed
# 2      Nevada       No   Premium  Bachelor           2/19/11         Employed
# 3  California       No     Basic  Bachelor           1/20/11       Unemployed
# 4  Washington       No     Basic  Bachelor            2/3/11         Employed
#
#   Gender Location Code Marital Status     Policy Type Renew Offer Type  \
# 0      F      Suburban        Married  Corporate Auto           Offer1
# 1      F      Suburban         Single   Personal Auto           Offer3
# 2      F      Suburban        Married   Personal Auto           Offer1
# 3      M      Suburban        Married  Corporate Auto           Offer1
# 4      M         Rural         Single   Personal Auto           Offer1
#
#   Sales Channel  Vehicle Class Vehicle Size
# ...

# %%
'''
def L(value):
    if 'L1' in value: # for row in dataframe if "Mega" is in the row...
        name = value.split(' ')[0]
        categorical_df['L']= '1'
        elif 'L2' in value:
            name = value.split(' ')[0]
            categorical_df[' ']= '2'
        elif 'L3' in value:
            name = value.split(' ')[0]
            categorical_df['L']= '3'

            return categorical_df

categorical_df['Policy']= categorical_df['Policy'].apply(L)
I tried running this and it did, but if I tried to display the head to check the result it will not work and display the following error:

Kernel Restarting
The kernel appears to have died. It will restart automatically.'''
# Out:
# '\ndef L(value):\n    if \'L1\' in value: # for row in dataframe if "Mega" is in the row...\n        name = value.split(\' \')[0]\n        categorical_df[\'L\']= \'1\'\n        elif \'L2\' in value:\n            name = value.split(\' \')[0]\n            categorical_df[\' \']= \'2\'\n        elif \'L3\' in value:\n            name = value.split(\' \')[0]\n            categorical_df[\'L\']= \'3\'\n\n            return categorical_df\n\ncategorical_df[\'Policy\']= categorical_df[\'Policy\'].apply(L)\nI tried running this and it did, but if I tried to display the head to check the result it will not work and display the following error:\n\nKernel Restarting\nThe kernel appears to have died. It will restart automatically.'

# %%
# I tried my best but I doesn't work. Life is hard, but as it does not a big deal we can keep that column where it is

# %% [markdown]
# 7. Would you choose to do anything else to clean or wrangle the categorical data?  Comment your decisions.

# %%
categorical_df.head(60)
# Out:
#          State Response  Coverage             Education Effective To Date  \
# 0   Washington       No     Basic              Bachelor           2/24/11
# 1      Arizona       No  Extended              Bachelor           1/31/11
# 2       Nevada       No   Premium              Bachelor           2/19/11
# 3   California       No     Basic              Bachelor           1/20/11
# 4   Washington       No     Basic              Bachelor            2/3/11
# 5       Oregon      Yes     Basic              Bachelor           1/25/11
# 6       Oregon      Yes     Basic               College           2/24/11
# 7      Arizona       No   Premium                Master           1/18/11
# 8       Oregon      Yes     Basic              Bachelor           1/26/11
# 9       Oregon       No  Extended               College           2/17/11
# 10  California       No     Basic               College           2/21/11
# 11  California       No     Basic               College            1/6/11
# ...

# %% [markdown]
# 8. Compare policy_type and policy.  What information is contained in these columns.  Can you identify what is important?

# %% [markdown]
# 9. Check number of unique values in each column, can they be combined in any way to ease encoding?  Comment your thoughts and make those changes.

# %%
for x in categorical_df:
    print(x,len(pd.unique(categorical_df[x].values.ravel('K'))))
# Out:
# State 5
# Response 2
# Coverage 3
# Education 5
# Effective To Date 59
# EmploymentStatus 5
# Gender 2
# Location Code 3
# Marital Status 3
# Policy Type 3
# Renew Offer Type 4
# Sales Channel 4
# Vehicle Class 6
# Vehicle Size 3

# %% [markdown]
# ![logo_ironhack_blue 7](https://user-images.githubusercontent.com/23629340/40541063-a07a0a8a-601a-11e8-91b5-2f13e4e6b441.png)
#
# # Lab | Feature extraction
#
# For this lab, we will be using the same dataset we used in the previous labs. We recommend using the same notebook since you will be reusing the same variables you previous created and used in labs.

# %% [markdown]
# ### Instructions

# %% [markdown]
# 1. Open the `categoricals` variable we created before.
#
# ```python
# categoricals = data.select_dtypes(np.object)
# categoricals.head()
# ```

# %%
categoricals = categorical_df.select_dtypes(np.object)
categoricals.head()
# Out:
# C:\Users\Jose María\AppData\Local\Temp\ipykernel_23636\3595458896.py:1: DeprecationWarning: `np.object` is a deprecated alias for the builtin `object`. To silence this warning, use `object` by itself. Doing this will not modify any behavior and is safe.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   categoricals = categorical_df.select_dtypes(np.object)
#         State Response  Coverage Education Effective To Date EmploymentStatus  \
# 0  Washington       No     Basic  Bachelor           2/24/11         Employed
# 1     Arizona       No  Extended  Bachelor           1/31/11       Unemployed
# 2      Nevada       No   Premium  Bachelor           2/19/11         Employed
# 3  California       No     Basic  Bachelor           1/20/11       Unemployed
# 4  Washington       No     Basic  Bachelor            2/3/11         Employed
#
#   Gender Location Code Marital Status     Policy Type Renew Offer Type  \
# ...

# %% [markdown]
# 2. Plot all the categorical variables with the proper plot. What can you see?

# %%
# Plot the all the categories per column as a countplot 

for column in categoricals.columns:
    if column != 'Effective To Date': # Lets life the date for another more representative plot
        plt.figure(figsize=(8,5))
        sns.countplot( x=categoricals[column], data=categoricals, palette='rainbow')
        plt.xticks(rotation = 45)
        plt.title(column+" divided by Class")
    else:
        pass

# %%
# We could also plot response in a pieplot
Response= categoricals.groupby("Response")["Response"].count()
Response.plot.pie(autopct='%1.1f%%', shadow=True, startangle=90)
# Out:
# <AxesSubplot:ylabel='Response'>

# %% [markdown]
# 3. There might be some columns that seem to be redundant, check their values to be sure. What should we do with them?

# %%
categoricals.head() # keep them
# Out:
#         State Response  Coverage Education Effective To Date EmploymentStatus  \
# 0  Washington       No     Basic  Bachelor           2/24/11         Employed
# 1     Arizona       No  Extended  Bachelor           1/31/11       Unemployed
# 2      Nevada       No   Premium  Bachelor           2/19/11         Employed
# 3  California       No     Basic  Bachelor           1/20/11       Unemployed
# 4  Washington       No     Basic  Bachelor            2/3/11         Employed
#
#   Gender Location Code Marital Status     Policy Type Renew Offer Type  \
# 0      F      Suburban        Married  Corporate Auto           Offer1
# 1      F      Suburban         Single   Personal Auto           Offer3
# 2      F      Suburban        Married   Personal Auto           Offer1
# 3      M      Suburban        Married  Corporate Auto           Offer1
# 4      M         Rural         Single   Personal Auto           Offer1
#
#   Sales Channel  Vehicle Class Vehicle Size
# ...

# %% [markdown]
# 4. Plot time variable. Can you extract something from it?

# %%
import datetime
import random
import matplotlib.pyplot as plt
def datetime_format(file):
    # Apply a datetime format
    file['Effective To Date'] = pd.to_datetime(file['Effective To Date'], format = "%m/%d/%y", errors='coerce')
    file['Effective To Date']= pd.to_datetime(file['Effective To Date'])
    return file
customer_df = datetime_format(categoricals)

# %%
categoricals['Effective To Date'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 9134 entries, 0 to 9133
# Series name: Effective To Date
# Non-Null Count  Dtype
# --------------  -----
# 9134 non-null   datetime64[ns]
# dtypes: datetime64[ns](1)
# memory usage: 71.5 KB

# %%
x=categoricals[['Effective To Date']]
y = []
i=0
for i in range(9134):
    y.append(i)

# %%
# make up some data
'''x =  [categoricals['Effective To Date'] + datetime.timedelta(hours=i) for i in range(12)]
y = [i+random.gauss(0,1) for i,_ in enumerate(x)]
      plt.figure(figsize=(8,5))
        sns.countplot( x=[column], data=categoricals, palette='rainbow')
        plt.xticks(rotation = 45)'''


x['y'] = y
x = x.set_index('Effective To Date')
plt.plot(x)
plt.gcf().autofmt_xdate()
plt.show()
# Out:
# C:\Users\Jose María\AppData\Local\Temp\ipykernel_23636\335421692.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x['y'] = y
